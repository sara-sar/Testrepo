# %%
# Import required libraries

# !pip install dash

# !pip install dash==1.19.0!

# !pip install jupyter_dash

# !pip install --upgrade plotly

# !pip install jupyter_plotly_dash

from jupyter_plotly_dash import JupyterDash
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application

app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id ='site-dropdown',
                                            options=[
                                                    {'label': 'All Sites', 'value': 'ALL'},
                                                    {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                    {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                    {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                    {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                    ],
                                            value='ALL',
                                            placeholder="Select a Launch Site here",
                                            searchable=True
                                            ),                                
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                html.P("Payload range (Kg):"),
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),
                                
                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig
        
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='jupyterlab', port = 8090, dev_tools_ui=True, debug=True,dev_tools_hot_reload =True, threaded=True)
# Out:
# Collecting dash
#   Downloading dash-2.5.1-py3-none-any.whl (9.8 MB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting plotly>=5.0.0
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting flask-compress
#   Downloading Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\saraf\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saraf\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
# Installing collected packages: tenacity, brotli, plotly, flask-compress, dash-table, dash-html-components, dash-core-components, dash
# Successfully installed brotli-1.0.9 dash-2.5.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.12 plotly-5.9.0 tenacity-8.0.1
# ERROR: Could not find a version that satisfies the requirement dash==1.19.0!
# ERROR: No matching distribution found for dash==1.19.0!
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: flask in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: requests in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (2.25.1)
# Requirement already satisfied: nest-asyncio in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (1.5.1)
# Requirement already satisfied: ipykernel in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: dash in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (2.5.1)
# Collecting ansi2html
#   Downloading ansi2html-1.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipython in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.9.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\saraf\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.12)
# Requirement already satisfied: click>=5.1 in c:\users\saraf\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\saraf\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\saraf\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\saraf\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saraf\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\saraf\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\saraf\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: decorator in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: colorama in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: pygments in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: backcall in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: pickleshare in c:\users\saraf\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\saraf\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\saraf\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\saraf\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\saraf\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\saraf\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saraf\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saraf\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\saraf\anaconda3\lib\site-packages (from requests->jupyter_dash) (4.0.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=52aa5ce24eeda58338a6ebf2f3036d6f85f7969f155fd334e93cc8bbed60b5fc
#   Stored in directory: c:\users\saraf\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.7.0 jupyter-dash-0.4.2 retrying-1.3.3
# Requirement already satisfied: plotly in c:\users\saraf\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\saraf\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Collecting jupyter_plotly_dash
#   Downloading jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: jupyter in c:\users\saraf\anaconda3\lib\site-packages (from jupyter_plotly_dash) (1.0.0)
# Collecting django-plotly-dash
#   Downloading django_plotly_dash-2.0.0-py3-none-any.whl (52 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp38-cp38-win_amd64.whl (555 kB)
# Collecting django-bootstrap4
#   Downloading django_bootstrap4-22.1-py3-none-any.whl (24 kB)
# Collecting dpd-components
#   Downloading dpd_components-0.1.0.tar.gz (4.3 kB)
# Collecting dpd-static-support
#   Downloading dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
# Collecting nbserverproxy
#   Downloading nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\saraf\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (20.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-win_amd64.whl (33 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-win_amd64.whl (122 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: idna>=2.0 in c:\users\saraf\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (2.10)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in c:\users\saraf\anaconda3\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.9.3)
# Collecting Django>=2.2
#   Downloading Django-4.0.5-py3-none-any.whl (8.0 MB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saraf\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.2.1)
# Collecting tzdata
#   Downloading tzdata-2022.1-py2.py3-none-any.whl (339 kB)
# Collecting asgiref<4,>=3.4.1
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting Werkzeug<2.1,>=2.0
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting dash-bootstrap-components<1
#   Downloading dash_bootstrap_components-0.13.1-py3-none-any.whl (197 kB)
# Requirement already satisfied: plotly in c:\users\saraf\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (5.9.0)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\saraf\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.2)
# Requirement already satisfied: dash>=2.0 in c:\users\saraf\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (2.5.1)
# Collecting Django>=2.2
#   Downloading Django-3.2.13-py3-none-any.whl (7.9 MB)
# Collecting channels<3.0
#   Downloading channels-2.4.0-py2.py3-none-any.whl (37 kB)
# Collecting daphne~=2.3
#   Downloading daphne-2.5.0-py2.py3-none-any.whl (26 kB)
# Collecting autobahn>=0.18
#   Downloading autobahn-22.5.1.tar.gz (435 kB)
# Collecting twisted[tls]>=18.7
#   Downloading Twisted-22.4.0-py3-none-any.whl (3.1 MB)
# Collecting txaio>=21.2.1
#   Downloading txaio-22.2.1-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: cryptography>=3.4.6 in c:\users\saraf\anaconda3\lib\site-packages (from autobahn>=0.18->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (3.4.7)
# Collecting hyperlink>=21.0.0
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
# Requirement already satisfied: setuptools in c:\users\saraf\anaconda3\lib\site-packages (from autobahn>=0.18->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (52.0.0.post20210125)
# Requirement already satisfied: cffi>=1.12 in c:\users\saraf\anaconda3\lib\site-packages (from cryptography>=3.4.6->autobahn>=0.18->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\saraf\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn>=0.18->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (2.20)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (5.0.0)
# Requirement already satisfied: flask-compress in c:\users\saraf\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (1.12)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (2.0.0)
# Requirement already satisfied: pytz in c:\users\saraf\anaconda3\lib\site-packages (from Django>=2.2->django-bootstrap4->jupyter_plotly_dash) (2021.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\saraf\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saraf\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\saraf\anaconda3\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (8.0.1)
# Collecting Automat>=0.8.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\saraf\anaconda3\lib\site-packages (from twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (3.7.4.3)
# Collecting twisted-iocpsupport<2,>=1.0.2
#   Downloading twisted_iocpsupport-1.0.2-cp38-cp38-win_amd64.whl (45 kB)
# Collecting incremental>=21.3.0
#   Downloading incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: zope.interface>=4.4.2 in c:\users\saraf\anaconda3\lib\site-packages (from twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (5.3.0)
# Requirement already satisfied: pyopenssl>=16.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (20.0.1)
# Collecting service-identity>=18.1.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in c:\users\saraf\anaconda3\lib\site-packages (from Automat>=0.8.0->twisted[tls]>=18.7->daphne~=2.3->channels<3.0->django-plotly-dash->jupyter_plotly_dash) (1.15.0)
# Collecting pyasn1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: brotli in c:\users\saraf\anaconda3\lib\site-packages (from flask-compress->dash>=2.0->django-plotly-dash->jupyter_plotly_dash) (1.0.9)
# Requirement already satisfied: ipywidgets in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (7.6.3)
# Requirement already satisfied: ipykernel in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.3.4)
# Requirement already satisfied: jupyter-console in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.4.0)
# Requirement already satisfied: notebook in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.3.0)
# Requirement already satisfied: nbconvert in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.0.7)
# Requirement already satisfied: qtconsole in c:\users\saraf\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.0.3)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (5.0.5)
# Requirement already satisfied: tornado>=4.2 in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.22.0)
# Requirement already satisfied: pickleshare in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: pygments in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: colorama in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: decorator in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (3.0.17)
# Requirement already satisfied: backcall in c:\users\saraf\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\saraf\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\saraf\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\saraf\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\saraf\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (5.1.3)
# Requirement already satisfied: jupyter-core in c:\users\saraf\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\saraf\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\saraf\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (0.17.3)
# Requirement already satisfied: prometheus-client in c:\users\saraf\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.10.1)
# Requirement already satisfied: argon2-cffi in c:\users\saraf\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\saraf\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\saraf\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (20.0.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\saraf\anaconda3\lib\site-packages (from notebook->jupyter->jupyter_plotly_dash) (0.9.4)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saraf\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->jupyter->jupyter_plotly_dash) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\saraf\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->jupyter_plotly_dash) (0.5.7)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.3)
# Requirement already satisfied: testpath in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: bleach in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\saraf\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\saraf\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\saraf\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\saraf\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: packaging in c:\users\saraf\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\saraf\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->jupyter->jupyter_plotly_dash) (2.4.7)
# Requirement already satisfied: qtpy in c:\users\saraf\anaconda3\lib\site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (1.9.0)
# Building wheels for collected packages: autobahn, dpd-components
#   Building wheel for autobahn (setup.py): started
#   Building wheel for autobahn (setup.py): finished with status 'done'
#   Created wheel for autobahn: filename=autobahn-22.5.1-cp38-cp38-win_amd64.whl size=603392 sha256=ce370dec25f5c71fd2661bc14572bcf054f3dbaaa66ef5eb5aff2e36a9e49eb8
#   Stored in directory: c:\users\saraf\appdata\local\pip\cache\wheels\5a\79\11\20abbf0edd7a8446f4023706b814a1668a4d23651f0616399a
#   Building wheel for dpd-components (setup.py): started
#   Building wheel for dpd-components (setup.py): finished with status 'done'
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4566 sha256=ce376de549a23b12810407ca085920e45a1def6d079a9191e18dc309c7958f48
#   Stored in directory: c:\users\saraf\appdata\local\pip\cache\wheels\07\a3\74\51b984d053f5e36de2d3bdfeb5dbadec7896d0af2dd7f4446e
# Successfully built autobahn dpd-components
# Installing collected packages: pyasn1, Werkzeug, twisted-iocpsupport, pyasn1-modules, incremental, hyperlink, constantly, Automat, txaio, twisted, service-identity, sqlparse, autobahn, asgiref, multidict, frozenlist, Django, daphne, yarl, dpd-components, dash-bootstrap-components, charset-normalizer, channels, async-timeout, aiosignal, nbserverproxy, dpd-static-support, django-plotly-dash, django-bootstrap4, aiohttp, jupyter-plotly-dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
# Successfully installed Automat-20.2.0 Django-3.2.13 Werkzeug-2.0.3 aiohttp-3.8.1 aiosignal-1.2.0 asgiref-3.5.2 async-timeout-4.0.2 autobahn-22.5.1 channels-2.4.0 charset-normalizer-2.1.0 constantly-15.1.0 daphne-2.5.0 dash-bootstrap-components-0.13.1 django-bootstrap4-22.1 django-plotly-dash-2.0.0 dpd-components-0.1.0 dpd-static-support-0.0.5 frozenlist-1.3.0 hyperlink-21.0.0 incremental-21.3.0 jupyter-plotly-dash-0.4.3 multidict-6.0.2 nbserverproxy-0.8.8 pyasn1-0.4.8 pyasn1-modules-0.2.8 service-identity-21.1.0 sqlparse-0.4.2 twisted-22.4.0 twisted-iocpsupport-1.0.2 txaio-22.2.1 yarl-1.7.2
# <ipython-input-1-d7f8aef3cdb5>:16: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-1-d7f8aef3cdb5>:17: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d7f8aef3cdb5> in <module>
#      20
#      21 # Read the airline data into pandas dataframe
# ---> 22 spacex_df = pd.read_csv("spacex_launch_dash.csv")
#      23 max_payload = spacex_df['Payload Mass (kg)'].max()
#      24 min_payload = spacex_df['Payload Mass (kg)'].min()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spacex_launch_dash.csv'
